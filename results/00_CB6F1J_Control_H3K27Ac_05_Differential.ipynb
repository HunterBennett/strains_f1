# %% [markdown]
# Hunter Bennett | Glass Lab | Kupffer Strains Project | 4 June 2021
#
# This is a re-vamp of the differential peak calling pipeline for comparisons within strains in a given condition (healthy, CCl4, NASH). This pipeline takes in ATAC-seq peaks annotated with H3K27Ac ChIP-seq data (or other histone modified data) from three strains (c57, balb, and aj) and compares each strain to the other pairwise. The main outputs of this file are:
# 1. A homer differential peak file containing each pairwise comparison.
# 2. Scatterplots of each pairwise comparison with significant peaks highlighted.
# 3. Heatmaps of differential peaks across all comparisons to highlight patterns.
# 4. Peak files for GREAT analysis of functional annotations associated with genomic regions.

# %%
### header ###
__author__ = "Hunter Bennett"
__license__ = "BSD"
__email__ = "hunter.r.bennett@gmail.com"
# %load_ext autoreload
# %autoreload 2
### imports ###
import sys
# %matplotlib inline
import os
import re
import glob
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
matplotlib.rcParams['savefig.dpi'] = 200
sns.set(font_scale=1)
sns.set_context('talk')
sns.set_style('white')

# import custom functions
import sys
sys.path.insert(0, '/home/h1bennet/code/')
from hbUtils import ngs_qc, quantile_normalize_df
from plotting_scripts import label_point, pca_rpkm_mat, get_diff_volcano
from homer_preprocessing import read_annotated_peaks, import_homer_diffpeak, pull_comparisons_get_diff

# %%
controlDirectory = '/home/h1bennet/strains/data/ATAC/control_f1/'
workingDirectory = '/home/h1bennet/strains_f1/results/00_CB6F1_Control/'
if not os.path.isdir(workingDirectory):
    os.mkdir(workingDirectory)
os.chdir(workingDirectory)

# %% [markdown]
# ### Read in raw gene expression files

# %%
df, mat = read_annotated_peaks('./peakQuan/allRawTags.txt')

# %%
best_reps = ['/home/h1bennet/strains/data/H3K27Ac/control_f1/tag_only_muts_mouse_cb6f1j_Male_Kupffer_ChIP_H3K27ac_Chow_healthyoung_CB61A_TDT_l20201212_AGTTCAGG_CCAACAGA_S23_L001.mm10.bowtie2.sam',
       '/home/h1bennet/strains/data/H3K27Ac/control_f1/tag_only_muts_mouse_cb6f1j_Male_Kupffer_ChIP_H3K27ac_Chow_healthyoung_CB61BC_TDT_l20201212_GACCTGAA_TTGGTGAG_S24_L001.mm10.bowtie2.sam',
       '/home/h1bennet/strains/data/H3K27Ac/control_f1/tag_only_muts_mouse_cb6f1j_Male_Kupffer_ChIP_H3K27ac_Chow_healthyoung_CB61D_TDT_l20201212_TCTCTACT_CGCGGTTC_S25_L001.mm10.bowtie2.sam',
       '/home/h1bennet/strains/data/H3K27Ac/control_f1/tag_only_muts_mouse_cb6f1j_Male_Kupffer_ChIP_H3K27ac_Chow_healthyoung_CB61A_TDT_l20201212_AGTTCAGG_CCAACAGA_S23_L001.balbcj.bowtie2_shifted_from_BALBCJ.sam',
       '/home/h1bennet/strains/data/H3K27Ac/control_f1/tag_only_muts_mouse_cb6f1j_Male_Kupffer_ChIP_H3K27ac_Chow_healthyoung_CB61BC_TDT_l20201212_GACCTGAA_TTGGTGAG_S24_L001.balbcj.bowtie2_shifted_from_BALBCJ.sam',
       '/home/h1bennet/strains/data/H3K27Ac/control_f1/tag_only_muts_mouse_cb6f1j_Male_Kupffer_ChIP_H3K27ac_Chow_healthyoung_CB61D_TDT_l20201212_TCTCTACT_CGCGGTTC_S25_L001.balbcj.bowtie2_shifted_from_BALBCJ.sam']

# %%
# import annotation file
df, mat = read_annotated_peaks('./peakQuan/allRawTags.txt')

# pull out selected samples
tst = np.append(np.asarray([True]*18, 'bool'), mat.columns.str.contains('|'.join(best_reps)))
df= df.loc[:, tst]
mat = mat.loc[:, mat.columns.str.contains('|'.join(best_reps))]

df.to_csv('./peakQuan/allRawTags_onlymuts.txt', sep='\t')


# also save version that filters based on amounts of tags
groups = [[0,1,2],
         [3,4,5]]
thresh = 4
n_passing_thresh=2

peaks = []
for group in groups:
    bool_peaks = (mat.iloc[:, group] > thresh).sum(1)>n_passing_thresh
    peaks.extend(mat.index[bool_peaks])
                  
mat_filt = mat.reindex(set(peaks)).dropna()
df_filt = df.reindex(set(peaks)).dropna()

print("N IDR Peaks:", mat.shape[0])
print("N Peaks Passing Thresh:", len(set(peaks)))
print("N Filtered Peaks:", mat_filt.shape[0])

df_filt.to_csv('./peakQuan/allRawTags_onlymuts_filtered_peaks.txt', sep='\t')
# Out:
# N IDR Peaks: 137971
# N Peaks Passing Thresh: 22655
# N Filtered Peaks: 22655

# %% [markdown]
# ### Run Differential Peaks for All Samples

# %%
# %%bash

# source activate deseq_36
# getDiffExpression.pl ./peakQuan/allRawTags_onlymuts.txt \
# 00_cb6f1_c57 00_cb6f1_c57 00_cb6f1_c57 \
# 01_cb6f1_balb 01_cb6f1_balb 01_cb6f1_balb \
# -peaks > ./diff_output.txt

# %%
# %%bash

# source activate deseq_36
# getDiffExpression.pl ./peakQuan/allRawTags_onlymuts_filtered_peaks.txt \
# 00_cb6f1_c57 00_cb6f1_c57 00_cb6f1_c57 \
# 01_cb6f1_balb 01_cb6f1_balb 01_cb6f1_balb \
# -peaks > ./diff_output_filtered_peaks.txt

# %% [markdown]
# # Scatter plot of differentially acetylated enhancers

# %%
log2fc = np.log2(2)
pval = 0.05

# %% [markdown]
# ## Unfiltered peaks...

# %%
diff_peak, peaks, peak_mat, peak_mat_quant = import_homer_diffpeak(
    './diff_output.txt',
    './peakQuan/allRawTags_onlymuts.txt')

comp_dict = pull_comparisons_get_diff(diff_peak, seq_type='Peak')
comp_dict.keys()
# Out:
# annotatePeaks all peaks (137971, 24)
# getDiffExpression selected transcripts (137971, 27)
# annotatePeaks selected peaks (137971, 24)
# dict_keys(['00_cb6f1_c57 vs. 01_cb6f1_balb'])

# %%
comps = ['00_cb6f1_c57 vs. 01_cb6f1_balb']

groups = [[[0,1,2],[3,4,5]]]

cols = []
for i in groups:
    for j in i:
        cols.extend(j)
cols = [cols]

colors = [['#3182bd', '#31a354']]

# %%
for key, col, group, color in zip(comps, cols, groups, colors):
    
    # make columns for plotting
    de = comp_dict[key]
    de['logtpm'] = np.log2(peak_mat.iloc[:, col].mean(1)+1)
    de['log10p'] = -np.log10(de.adj_pval + 10**(-50))
    de['g0_mean'] = np.log2(peak_mat.iloc[:, group[0]].mean(1)+1)
    de['g1_mean'] = np.log2(peak_mat.iloc[:, group[1]].mean(1)+1)
    de = de.reindex(de.index[(de.g0_mean >= 3) | (de.g1_mean >= 3)])

    dot_colors = []
    dot_sizes = []
    
    # create dot size list
    for index, row in de.iterrows():
        if (row.adj_pval <= pval) & (-row.log2fc < -log2fc):
            dot_colors.append(color[1])
            dot_sizes.append(row.log10p)
        elif (row.adj_pval <= pval) & (-row.log2fc > log2fc):
            dot_colors.append(color[0])
            dot_sizes.append(row.log10p)
        else:
            dot_colors.append('grey')
            dot_sizes.append(0.5)
    
    # print DE peaks
    print(key)
    print('N peaks downregulated', np.sum((de.adj_pval <= pval) & (de.log2fc < -log2fc)))
    print('N peaks upregulated', np.sum((de.adj_pval <= pval) & (de.log2fc > log2fc)))
    print('')
    
    fig, ax = plt.subplots(figsize=(4,4))
    
        # plot group by group scatter:
    ax.scatter(
        x=de.g0_mean,
        y=de.g1_mean,
        s=0.5, #de.log10p+0.05,
        c=dot_colors)
    
    ax.set_xlabel(key.split(' vs. ')[0] + ' Mean Tags')
    ax.set_ylabel(key.split(' vs. ')[1] + ' Mean Tags')
    
    #set max and min
    countmax = np.max([np.max(de.g0_mean), np.max(de.g1_mean)])
    ax.set_xlim([0,np.ceil(countmax)])
    ax.set_ylim([0,np.ceil(countmax)])
    
#     ax.text(0.5,15,
#         s='%d %s spec peaks' % (np.sum((de.adj_pval <= 0.05) & (de.log2fc > 1)), key.split(' vs. ')[1]),
#         fontsize=12,
#         c=color[1])
#     ax.text(15,0.5,
#         s='%d %s spec peaks' % (np.sum((de.adj_pval <= 0.05) & (de.log2fc < -1)), key.split(' vs. ')[0]),
#         fontsize=12,
#         c=color[0],
#         rotation=-90)
    
    plt.savefig('./figures/'+key+'_scatter_notext.png', bbox_inches='tight')
    # plt.close()
# Out:
# 00_cb6f1_c57 vs. 01_cb6f1_balb
# N peaks downregulated 1204
# N peaks upregulated 945

# %% [markdown]
# # Filtered peaks

# %%
diff_peak, peaks, peak_mat, peak_mat_quant = import_homer_diffpeak(
    './diff_output_filtered_peaks.txt',
    './peakQuan/allRawTags_onlymuts_filtered_peaks.txt')

comp_dict = pull_comparisons_get_diff(diff_peak, seq_type='Peak')
comp_dict.keys()
# Out:
# annotatePeaks all peaks (21281, 24)
# getDiffExpression selected transcripts (21281, 27)
# annotatePeaks selected peaks (21281, 24)
# dict_keys(['00_cb6f1_c57 vs. 01_cb6f1_balb'])

# %%
comps = ['00_cb6f1_c57 vs. 01_cb6f1_balb']

groups = [[[0,1,2],[3,4,5]]]

cols = []
for i in groups:
    for j in i:
        cols.extend(j)
cols = [cols]

colors = [['#3182bd', '#31a354']]

# %%
for key, col, group, color in zip(comps, cols, groups, colors):
    
    # make columns for plotting
    de = comp_dict[key]
    de['logtpm'] = np.log2(peak_mat.iloc[:, col].mean(1)+1)
    de['log10p'] = -np.log10(de.adj_pval + 10**(-50))
    de['g0_mean'] = np.log2(peak_mat.iloc[:, group[0]].mean(1)+1)
    de['g1_mean'] = np.log2(peak_mat.iloc[:, group[1]].mean(1)+1)
    de = de.reindex(de.index[(de.g0_mean >= 3) | (de.g1_mean >= 3)])

    dot_colors = []
    dot_sizes = []
    
    # create dot size list
    for index, row in de.iterrows():
        if (row.adj_pval <= pval) & (-row.log2fc < -log2fc):
            dot_colors.append(color[1])
            dot_sizes.append(row.log10p)
        elif (row.adj_pval <= pval) & (-row.log2fc > log2fc):
            dot_colors.append(color[0])
            dot_sizes.append(row.log10p)
        else:
            dot_colors.append('grey')
            dot_sizes.append(0.5)
    
    # print DE peaks
    print(key)
    print('N peaks downregulated', np.sum((de.adj_pval <= pval) & (de.log2fc < -log2fc)))
    print('N peaks upregulated', np.sum((de.adj_pval <= pval) & (de.log2fc > log2fc)))
    print('')
    
    fig, ax = plt.subplots(figsize=(4,4))
    
        # plot group by group scatter:
    ax.scatter(
        x=de.g0_mean,
        y=de.g1_mean,
        s=0.5, #de.log10p+0.05,
        c=dot_colors)
    
    ax.set_xlabel(key.split(' vs. ')[0] + ' Mean Tags')
    ax.set_ylabel(key.split(' vs. ')[1] + ' Mean Tags')
    
    #set max and min
    countmax = np.max([np.max(de.g0_mean), np.max(de.g1_mean)])
    ax.set_xlim([0,np.ceil(countmax)])
    ax.set_ylim([0,np.ceil(countmax)])
    
#     ax.text(0.5,15,
#         s='%d %s spec peaks' % (np.sum((de.adj_pval <= 0.05) & (de.log2fc > 1)), key.split(' vs. ')[1]),
#         fontsize=12,
#         c=color[1])
#     ax.text(15,0.5,
#         s='%d %s spec peaks' % (np.sum((de.adj_pval <= 0.05) & (de.log2fc < -1)), key.split(' vs. ')[0]),
#         fontsize=12,
#         c=color[0],
#         rotation=-90)
    
    plt.savefig('./figures/'+key+'_scatter_notext.png', bbox_inches='tight')
    # plt.close()
# Out:
# 00_cb6f1_c57 vs. 01_cb6f1_balb
# N peaks downregulated 1010
# N peaks upregulated 758

# %% [markdown]
# # Check Quality of Differential Calls

# %% [markdown]
# We will do this first by looking at overlap with some of the plots we have made previously...

# %%
diff_peak, peaks, peak_mat, peak_mat_quant = import_homer_diffpeak(
    './diff_output_filtered_peaks.txt',
    './peakQuan/allRawTags_onlymuts_filtered_peaks.txt')

comp_dict = pull_comparisons_get_diff(diff_peak, seq_type='Peak')
comp_dict.keys()
# Out:
# annotatePeaks all peaks (21281, 24)
# getDiffExpression selected transcripts (21281, 27)
# annotatePeaks selected peaks (21281, 24)
# dict_keys(['00_cb6f1_c57 vs. 01_cb6f1_balb'])

# %%
df = pd.read_csv('./peaks_with_asb_min_tag_filter.txt',
                 sep='\t',
                 index_col=0)

# %%
df['adj_pval'] = diff_peak['00_cb6f1_c57 vs. 01_cb6f1_balb adj. p-value']
color= ['#de2d26' if i < 0.05 else '#bdbdbd' for i in df['adj_pval']]

# %%
fig, ax = plt.subplots(figsize=(4,4))

ax.scatter(df['allelic_bias_only_muts'],
           df['allelic_bias_only_muts_mean_second'],
           c='#bdbdbd',
           s=2)

ax.scatter(df.loc[df.adj_pval < 0.05, 'allelic_bias_only_muts'],
           df.loc[df.adj_pval < 0.05, 'allelic_bias_only_muts_mean_second'],
           c='#de2d26',
           s=2)

ax.set_xlabel('Allelic Bias Mean TPM First')
ax.set_ylabel('Allelic Bias Mean TPM Second')
# Out:
# Text(0, 0.5, 'Allelic Bias Mean TPM Second')

# %%
fig, axs = plt.subplots(1,2, figsize=(8,3))
plt.subplots_adjust(wspace=0.4)

axs[0].scatter(df.loc[:, ['c57bl6j_tag_perfect', 'balbcj_tag_perfect']].mean(1),
               df.loc[:, 'mean_second_asb_mean'],
               c='#bdbdbd',
               s=2)

axs[0].scatter(df.loc[df.adj_pval < 0.05, ['c57bl6j_tag_perfect', 'balbcj_tag_perfect']].mean(1),
               df.loc[df.adj_pval < 0.05, 'mean_second_asb_mean'],
               c='#de2d26',
               s=2)

axs[0].set_ylabel('Fraction BALBcJ Alleles')
axs[0].set_xlabel('Mean H3K27Ac Tags');

axs[1].scatter(df.loc[:, ['c57bl6j_tag_perfect', 'balbcj_tag_perfect']].mean(1),
               df.loc[:, 'mean_second_asb_var'],
               c='#bdbdbd',
               s=2)

axs[1].scatter(df.loc[df.adj_pval < 0.05, ['c57bl6j_tag_perfect', 'balbcj_tag_perfect']].mean(1),
               df.loc[df.adj_pval < 0.05, 'mean_second_asb_var'],
               c='#de2d26',
               s=2)

axs[1].set_ylabel('ASB Variance')
axs[1].set_xlabel('Mean H3K27Ac Tags');

# %% [markdown]
# # Visual inspection of differential regions...

# %%
# make location column for peak dict (for examining on browser)
diff_peak['location'] = diff_peak.Chr + ':' + diff_peak.Start.map(str) + '-' + diff_peak.End.map(str)

diff_peak.to_csv('./diff_output_filtered_peaks_with_location.txt',
                 sep='\t')

# %%
diff_peak.columns
# Out:
# Index(['Chr', 'Start', 'End', 'Strand', 'Peak Score',
#        'Focus Ratio/Region Size', 'Annotation', 'Detailed Annotation',
#        'Distance to TSS', 'Nearest PromoterID', 'Entrez ID', 'Nearest Unigene',
#        'Nearest Refseq', 'Nearest Ensembl', 'Gene Name', 'Gene Alias',
#        'Gene Description', 'Gene Type',
#        '/home/h1bennet/strains/data/H3K27Ac/control_f1/tag_only_muts_mouse_cb6f1j_Male_Kupffer_ChIP_H3K27ac_Chow_healthyoung_CB61A_TDT_l20201212_AGTTCAGG_CCAACAGA_S23_L001.mm10.bowtie2.sam',
#        '/home/h1bennet/strains/data/H3K27Ac/control_f1/tag_only_muts_mouse_cb6f1j_Male_Kupffer_ChIP_H3K27ac_Chow_healthyoung_CB61BC_TDT_l20201212_GACCTGAA_TTGGTGAG_S24_L001.mm10.bowtie2.sam',
#        '/home/h1bennet/strains/data/H3K27Ac/control_f1/tag_only_muts_mouse_cb6f1j_Male_Kupffer_ChIP_H3K27ac_Chow_healthyoung_CB61D_TDT_l20201212_TCTCTACT_CGCGGTTC_S25_L001.mm10.bowtie2.sam',
#        '/home/h1bennet/strains/data/H3K27Ac/control_f1/tag_only_muts_mouse_cb6f1j_Male_Kupffer_ChIP_H3K27ac_Chow_healthyoung_CB61A_TDT_l20201212_AGTTCAGG_CCAACAGA_S23_L001.balbcj.bowtie2_shifted_from_BALBCJ.sam',
#        '/home/h1bennet/strains/data/H3K27Ac/control_f1/tag_only_muts_mouse_cb6f1j_Male_Kupffer_ChIP_H3K27ac_Chow_healthyoung_CB61BC_TDT_l20201212_GACCTGAA_TTGGTGAG_S24_L001.balbcj.bowtie2_shifted_from_BALBCJ.sam',
#        '/home/h1bennet/strains/data/H3K27Ac/control_f1/tag_only_muts_mouse_cb6f1j_Male_Kupffer_ChIP_H3K27ac_Chow_healthyoung_CB61D_TDT_l20201212_TCTCTACT_CGCGGTTC_S25_L001.balbcj.bowtie2_shifted_from_BALBCJ.sam',
#        '00_cb6f1_c57 vs. 01_cb6f1_balb Log2 Fold Change',
#        '00_cb6f1_c57 vs. 01_cb6f1_balb p-value',
#        '00_cb6f1_c57 vs. 01_cb6f1_balb adj. p-value', 'location'],
#       dtype='object')

# %%
viz_cols = ['Annotation', 'Distance to TSS', 'Gene Name', 'location', 'Annotation',
            '00_cb6f1_c57 vs. 01_cb6f1_balb Log2 Fold Change','00_cb6f1_c57 vs. 01_cb6f1_balb adj. p-value']
diff_peak_viz = diff_peak.loc[:, viz_cols]

# %%
diff_peak_viz.sort_values(
    '00_cb6f1_c57 vs. 01_cb6f1_balb adj. p-value', ascending=True).head(50)
# Out:
#                                                      Annotation  \
# PeakID
# Merged-chr15-88128622-3                              Intergenic
# Merged-chr4-141606079-4                promoter-TSS (NM_133754)
# Merged-chr7-16207700-4       intron (NM_027883, intron 7 of 16)
# Merged-chr17-33999651-4    intron (NM_001001892, intron 2 of 7)
# Merged-chr15-88129088-3                              Intergenic
# Merged-chr2-163764568-3                              Intergenic
# Merged-chr4-141605479-1       intron (NM_133754, intron 1 of 8)
# Merged-chr5-147060173-3       intron (NM_080795, intron 1 of 9)
# Merged-chr12-26439507-4                              Intergenic
# Merged-chr15-88127924-1                              Intergenic
# Merged-chr11-31733141-4                              Intergenic
# Merged-chr10-68204625-3       intron (NM_023598, intron 3 of 9)
# Merged-chr8-33673375-4       intron (NM_010344, intron 4 of 12)
# Merged-chr10-68204064-3       intron (NM_023598, intron 3 of 9)
# Merged-chr7-16207238-3       intron (NM_027883, intron 7 of 16)
# Merged-chr14-47362616-1                              Intergenic
# Merged-chr5-147059505-4       intron (NM_080795, intron 1 of 9)
# Merged-chr3-51184970-4                               Intergenic
# Merged-chr8-70645411-4                               Intergenic
# Merged-chr12-26438978-3                              Intergenic
# Merged-chr5-147063514-3       intron (NM_080795, intron 1 of 9)
# Merged-chr8-127440734-4     intron (NM_033620, intron 20 of 24)
# Merged-chr3-51185624-4                               Intergenic
# Merged-chr8-33653113-3                 promoter-TSS (NM_010344)
# Merged-chr7-35735455-3       intron (NM_178704, intron 3 of 18)
# Merged-chr7-104505898-3       intron (NM_199146, intron 1 of 7)
# Merged-chr4-141606776-2                promoter-TSS (NM_133754)
# Merged-chr4-6222229-4                                Intergenic
# Merged-chr8-70646107-4                          TTS (NM_023217)
# Merged-chr12-79168539-3       intron (NM_016800, intron 1 of 5)
# Merged-chr5-147063944-1       intron (NM_080795, intron 1 of 9)
# Merged-chr17-34057426-3      exon (NM_001317722, exon 36 of 65)
# Merged-chr17-27591947-3    intron (NM_001291046, intron 2 of 4)
# Merged-chr8-84420162-1    intron (NM_001252060, intron 1 of 47)
# Merged-chr14-47362896-1                              Intergenic
# Merged-chr4-133662543-3        exon (NM_001145956, exon 3 of 3)
# Merged-chr3-87401454-4   intron (NM_001310545, intron 10 of 10)
# Merged-chr3-103857544-3                              Intergenic
# Merged-chr17-26437510-5    intron (NM_001081656, intron 2 of 4)
# Merged-chr2-163765129-3                              Intergenic
# Merged-chr2-129914374-3                              Intergenic
# Merged-chr4-141646197-4   intron (NM_001347237, intron 1 of 18)
# Merged-chr9-47588532-3     intron (NM_001025600, intron 1 of 8)
# Merged-chr13-95494997-3                              Intergenic
# Merged-chr5-23850583-4                 promoter-TSS (NR_045040)
# Merged-chr4-43384257-3    intron (NM_001037709, intron 1 of 11)
# Merged-chr1-156066298-3      3' UTR (NM_001358627, exon 6 of 6)
# Merged-chr9-40710222-3        intron (NM_133733, intron 1 of 6)
# Merged-chr5-146829697-3                              Intergenic
# Merged-chr14-47361936-7                              Intergenic
#
#                          Distance to TSS      Gene Name  \
# PeakID
# Merged-chr15-88128622-3        -186233.0  B230214G05Rik
# Merged-chr4-141606079-4            -32.0         Fblim1
# Merged-chr7-16207700-4           14279.0          Dhx34
# Merged-chr17-33999651-4            711.0          H2-K1
# Merged-chr15-88129088-3        -185809.0  B230214G05Rik
# Merged-chr2-163764568-3         -14343.0            Ada
# Merged-chr4-141605479-1            573.0         Fblim1
# Merged-chr5-147060173-3          16412.0           Lnx2
# Merged-chr12-26439507-4          16994.0          Rsad2
# Merged-chr15-88127924-1        -186950.0  B230214G05Rik
# Merged-chr11-31733141-4         -61273.0           Bod1
# Merged-chr10-68204625-3          74109.0         Arid5b
# Merged-chr8-33673375-4           20106.0            Gsr
# Merged-chr10-68204064-3          74651.0         Arid5b
# Merged-chr7-16207238-3           14841.0          Dhx34
# Merged-chr14-47362616-1         -11244.0         Lgals3
# Merged-chr5-147059505-4          17086.0           Lnx2
# Merged-chr3-51184970-4          -39464.0           Noct
# Merged-chr8-70645411-4          -12951.0          Gdf15
# Merged-chr12-26438978-3          17538.0          Rsad2
# Merged-chr5-147063514-3          13046.0           Lnx2
# Merged-chr8-127440734-4         141087.0          Pard3
# Merged-chr3-51185624-4          -38814.0           Noct
# Merged-chr8-33653113-3            -123.0            Gsr
# Merged-chr7-35735455-3           19002.0        Dpy19l3
# Merged-chr7-104505898-3           1937.0        Trim30d
# Merged-chr4-141606776-2           -700.0         Fblim1
# Merged-chr4-6222229-4            31132.0         Ubxn2b
# Merged-chr8-70646107-4           13565.0         Pgpep1
# Merged-chr12-79168539-3           3902.0          Vti1b
# Merged-chr5-147063944-1          12628.0           Lnx2
# Merged-chr17-34057426-3          18281.0        Col11a2
# Merged-chr17-27591947-3         -26145.0       AI413582
# Merged-chr8-84420162-1            4798.0        Cacna1a
# Merged-chr14-47362896-1         -10964.0         Lgals3
# Merged-chr4-133662543-3          10054.0           Pigv
# Merged-chr3-87401454-4           25109.0          Fcrl1
# Merged-chr3-103857544-3          -2249.0         Ptpn22
# Merged-chr17-26437510-5          22505.0        Neurl1b
# Merged-chr2-163765129-3         -14908.0            Ada
# Merged-chr2-129914374-3         -97959.0           Tgm3
# Merged-chr4-141646197-4          17920.0        Plekhm2
# Merged-chr9-47588532-3           58206.0          Cadm1
# Merged-chr13-95494997-3         -16338.0          S100z
# Merged-chr5-23850583-4              41.0  2700038G22Rik
# Merged-chr4-43384257-3            2275.0          Rusc2
# Merged-chr1-156066298-3          25433.0       Tor1aip2
# Merged-chr9-40710222-3           24320.0           Clmp
# Merged-chr5-146829697-3          -3199.0          Rpl21
# Merged-chr14-47361936-7         -11969.0         Lgals3
#
#                                          location  \
# PeakID
# Merged-chr15-88128622-3   chr15:88128141-88129141
# Merged-chr4-141606079-4  chr4:141605584-141606584
# Merged-chr7-16207700-4     chr7:16207214-16208214
# Merged-chr17-33999651-4   chr17:33999122-34000122
# Merged-chr15-88129088-3   chr15:88128565-88129565
# Merged-chr2-163764568-3  chr2:163764082-163765082
# Merged-chr4-141605479-1  chr4:141604979-141605979
# Merged-chr5-147060173-3  chr5:147059660-147060660
# Merged-chr12-26439507-4   chr12:26438958-26439958
# Merged-chr15-88127924-1   chr15:88127424-88128424
# Merged-chr11-31733141-4   chr11:31732635-31733635
# Merged-chr10-68204625-3   chr10:68204117-68205117
# Merged-chr8-33673375-4     chr8:33672844-33673844
# Merged-chr10-68204064-3   chr10:68203575-68204575
# Merged-chr7-16207238-3     chr7:16206652-16207652
# Merged-chr14-47362616-1   chr14:47362116-47363116
# Merged-chr5-147059505-4  chr5:147058986-147059986
# Merged-chr3-51184970-4     chr3:51184483-51185483
# Merged-chr8-70645411-4     chr8:70644907-70645907
# Merged-chr12-26438978-3   chr12:26438414-26439414
# Merged-chr5-147063514-3  chr5:147063026-147064026
# Merged-chr8-127440734-4  chr8:127440239-127441239
# Merged-chr3-51185624-4     chr3:51185133-51186133
# Merged-chr8-33653113-3     chr8:33652615-33653615
# Merged-chr7-35735455-3     chr7:35734952-35735952
# Merged-chr7-104505898-3  chr7:104505412-104506412
# Merged-chr4-141606776-2  chr4:141606252-141607252
# Merged-chr4-6222229-4        chr4:6221737-6222737
# Merged-chr8-70646107-4     chr8:70645673-70646673
# Merged-chr12-79168539-3   chr12:79168056-79169056
# Merged-chr5-147063944-1  chr5:147063444-147064444
# Merged-chr17-34057426-3   chr17:34056919-34057919
# Merged-chr17-27591947-3   chr17:27591372-27592372
# Merged-chr8-84420162-1     chr8:84419662-84420662
# Merged-chr14-47362896-1   chr14:47362396-47363396
# Merged-chr4-133662543-3  chr4:133662093-133663093
# Merged-chr3-87401454-4     chr3:87400996-87401996
# Merged-chr3-103857544-3  chr3:103857046-103858046
# Merged-chr17-26437510-5   chr17:26436970-26437970
# Merged-chr2-163765129-3  chr2:163764647-163765647
# Merged-chr2-129914374-3  chr2:129913881-129914881
# Merged-chr4-141646197-4  chr4:141645695-141646695
# Merged-chr9-47588532-3     chr9:47588058-47589058
# Merged-chr13-95494997-3   chr13:95494493-95495493
# Merged-chr5-23850583-4     chr5:23850138-23851138
# Merged-chr4-43384257-3     chr4:43383757-43384757
# Merged-chr1-156066298-3  chr1:156065794-156066794
# Merged-chr9-40710222-3     chr9:40709784-40710784
# Merged-chr5-146829697-3  chr5:146829191-146830191
# Merged-chr14-47361936-7   chr14:47361391-47362391
#
#                                                      Annotation  \
# PeakID
# Merged-chr15-88128622-3                              Intergenic
# Merged-chr4-141606079-4                promoter-TSS (NM_133754)
# Merged-chr7-16207700-4       intron (NM_027883, intron 7 of 16)
# Merged-chr17-33999651-4    intron (NM_001001892, intron 2 of 7)
# Merged-chr15-88129088-3                              Intergenic
# Merged-chr2-163764568-3                              Intergenic
# Merged-chr4-141605479-1       intron (NM_133754, intron 1 of 8)
# Merged-chr5-147060173-3       intron (NM_080795, intron 1 of 9)
# Merged-chr12-26439507-4                              Intergenic
# Merged-chr15-88127924-1                              Intergenic
# Merged-chr11-31733141-4                              Intergenic
# Merged-chr10-68204625-3       intron (NM_023598, intron 3 of 9)
# Merged-chr8-33673375-4       intron (NM_010344, intron 4 of 12)
# Merged-chr10-68204064-3       intron (NM_023598, intron 3 of 9)
# Merged-chr7-16207238-3       intron (NM_027883, intron 7 of 16)
# Merged-chr14-47362616-1                              Intergenic
# Merged-chr5-147059505-4       intron (NM_080795, intron 1 of 9)
# Merged-chr3-51184970-4                               Intergenic
# Merged-chr8-70645411-4                               Intergenic
# Merged-chr12-26438978-3                              Intergenic
# Merged-chr5-147063514-3       intron (NM_080795, intron 1 of 9)
# Merged-chr8-127440734-4     intron (NM_033620, intron 20 of 24)
# Merged-chr3-51185624-4                               Intergenic
# Merged-chr8-33653113-3                 promoter-TSS (NM_010344)
# Merged-chr7-35735455-3       intron (NM_178704, intron 3 of 18)
# Merged-chr7-104505898-3       intron (NM_199146, intron 1 of 7)
# Merged-chr4-141606776-2                promoter-TSS (NM_133754)
# Merged-chr4-6222229-4                                Intergenic
# Merged-chr8-70646107-4                          TTS (NM_023217)
# Merged-chr12-79168539-3       intron (NM_016800, intron 1 of 5)
# Merged-chr5-147063944-1       intron (NM_080795, intron 1 of 9)
# Merged-chr17-34057426-3      exon (NM_001317722, exon 36 of 65)
# Merged-chr17-27591947-3    intron (NM_001291046, intron 2 of 4)
# Merged-chr8-84420162-1    intron (NM_001252060, intron 1 of 47)
# Merged-chr14-47362896-1                              Intergenic
# Merged-chr4-133662543-3        exon (NM_001145956, exon 3 of 3)
# Merged-chr3-87401454-4   intron (NM_001310545, intron 10 of 10)
# Merged-chr3-103857544-3                              Intergenic
# Merged-chr17-26437510-5    intron (NM_001081656, intron 2 of 4)
# Merged-chr2-163765129-3                              Intergenic
# Merged-chr2-129914374-3                              Intergenic
# Merged-chr4-141646197-4   intron (NM_001347237, intron 1 of 18)
# Merged-chr9-47588532-3     intron (NM_001025600, intron 1 of 8)
# Merged-chr13-95494997-3                              Intergenic
# Merged-chr5-23850583-4                 promoter-TSS (NR_045040)
# Merged-chr4-43384257-3    intron (NM_001037709, intron 1 of 11)
# Merged-chr1-156066298-3      3' UTR (NM_001358627, exon 6 of 6)
# Merged-chr9-40710222-3        intron (NM_133733, intron 1 of 6)
# Merged-chr5-146829697-3                              Intergenic
# Merged-chr14-47361936-7                              Intergenic
#
#                          00_cb6f1_c57 vs. 01_cb6f1_balb Log2 Fold Change  \
# PeakID
# Merged-chr15-88128622-3                                         4.156292
# Merged-chr4-141606079-4                                        -3.478732
# Merged-chr7-16207700-4                                         -3.780850
# Merged-chr17-33999651-4                                        -2.905524
# Merged-chr15-88129088-3                                         5.209459
# Merged-chr2-163764568-3                                         3.838024
# Merged-chr4-141605479-1                                        -4.283524
# Merged-chr5-147060173-3                                         3.278847
# Merged-chr12-26439507-4                                         4.735661
# Merged-chr15-88127924-1                                         6.595007
# Merged-chr11-31733141-4                                        -4.167996
# Merged-chr10-68204625-3                                         4.113356
# Merged-chr8-33673375-4                                         -2.554492
# Merged-chr10-68204064-3                                         4.578837
# Merged-chr7-16207238-3                                         -3.030707
# Merged-chr14-47362616-1                                        -2.860749
# Merged-chr5-147059505-4                                         3.111226
# Merged-chr3-51184970-4                                         -1.872858
# Merged-chr8-70645411-4                                         -3.527110
# Merged-chr12-26438978-3                                         4.613501
# Merged-chr5-147063514-3                                         2.596638
# Merged-chr8-127440734-4                                        -4.200533
# Merged-chr3-51185624-4                                         -2.029569
# Merged-chr8-33653113-3                                         -2.001599
# Merged-chr7-35735455-3                                          3.300453
# Merged-chr7-104505898-3                                         3.771753
# Merged-chr4-141606776-2                                        -3.212048
# Merged-chr4-6222229-4                                          -4.018331
# Merged-chr8-70646107-4                                         -3.350309
# Merged-chr12-79168539-3                                         3.345025
# Merged-chr5-147063944-1                                         2.661171
# Merged-chr17-34057426-3                                        -3.827865
# Merged-chr17-27591947-3                                        -5.313125
# Merged-chr8-84420162-1                                          4.222626
# Merged-chr14-47362896-1                                        -3.600196
# Merged-chr4-133662543-3                                         5.095958
# Merged-chr3-87401454-4                                         -3.459684
# Merged-chr3-103857544-3                                        -2.740909
# Merged-chr17-26437510-5                                        -2.147056
# Merged-chr2-163765129-3                                         2.784714
# Merged-chr2-129914374-3                                         4.010048
# Merged-chr4-141646197-4                                        -1.789464
# Merged-chr9-47588532-3                                          3.094984
# Merged-chr13-95494997-3                                        -4.115785
# Merged-chr5-23850583-4                                         -3.115943
# Merged-chr4-43384257-3                                         -3.373098
# Merged-chr1-156066298-3                                        -3.887316
# Merged-chr9-40710222-3                                          4.550786
# Merged-chr5-146829697-3                                        -3.407705
# Merged-chr14-47361936-7                                        -1.548755
#
#                          00_cb6f1_c57 vs. 01_cb6f1_balb adj. p-value
# PeakID
# Merged-chr15-88128622-3                                 2.618090e-50
# Merged-chr4-141606079-4                                 4.043732e-47
# Merged-chr7-16207700-4                                  6.939621e-41
# Merged-chr17-33999651-4                                 9.323564e-39
# Merged-chr15-88129088-3                                 4.116063e-38
# Merged-chr2-163764568-3                                 4.494906e-32
# Merged-chr4-141605479-1                                 2.825304e-31
# Merged-chr5-147060173-3                                 2.049630e-30
# Merged-chr12-26439507-4                                 4.892336e-30
# Merged-chr15-88127924-1                                 4.850571e-29
# Merged-chr11-31733141-4                                 1.286418e-28
# Merged-chr10-68204625-3                                 6.589555e-28
# Merged-chr8-33673375-4                                  6.589555e-28
# Merged-chr10-68204064-3                                 1.467243e-27
# Merged-chr7-16207238-3                                  1.511572e-26
# Merged-chr14-47362616-1                                 1.731843e-26
# Merged-chr5-147059505-4                                 7.300727e-26
# Merged-chr3-51184970-4                                  1.029378e-25
# Merged-chr8-70645411-4                                  7.484670e-25
# Merged-chr12-26438978-3                                 1.204615e-24
# Merged-chr5-147063514-3                                 1.932251e-24
# Merged-chr8-127440734-4                                 2.545586e-24
# Merged-chr3-51185624-4                                  6.672270e-24
# Merged-chr8-33653113-3                                  6.672270e-24
# Merged-chr7-35735455-3                                  1.381521e-23
# Merged-chr7-104505898-3                                 3.308115e-23
# Merged-chr4-141606776-2                                 5.978889e-23
# Merged-chr4-6222229-4                                   1.158865e-22
# Merged-chr8-70646107-4                                  1.444176e-22
# Merged-chr12-79168539-3                                 1.656030e-22
# Merged-chr5-147063944-1                                 6.563549e-22
# Merged-chr17-34057426-3                                 1.090850e-21
# Merged-chr17-27591947-3                                 1.459872e-21
# Merged-chr8-84420162-1                                  2.293539e-21
# Merged-chr14-47362896-1                                 2.460697e-21
# Merged-chr4-133662543-3                                 5.080518e-21
# Merged-chr3-87401454-4                                  1.179875e-20
# Merged-chr3-103857544-3                                 1.240124e-20
# Merged-chr17-26437510-5                                 4.882887e-20
# Merged-chr2-163765129-3                                 2.264678e-19
# Merged-chr2-129914374-3                                 5.009975e-19
# Merged-chr4-141646197-4                                 1.221084e-18
# Merged-chr9-47588532-3                                  1.694314e-18
# Merged-chr13-95494997-3                                 3.076833e-18
# Merged-chr5-23850583-4                                  3.076833e-18
# Merged-chr4-43384257-3                                  4.953408e-18
# Merged-chr1-156066298-3                                 9.775462e-18
# Merged-chr9-40710222-3                                  1.057300e-17
# Merged-chr5-146829697-3                                 2.602667e-17
# Merged-chr14-47361936-7                                 2.817305e-17

# %%
diff_peak_viz.loc[diff_peak_viz['00_cb6f1_c57 vs. 01_cb6f1_balb adj. p-value'] <= 0.05, :].sort_values(
    '00_cb6f1_c57 vs. 01_cb6f1_balb adj. p-value', ascending=False).head()
# Out:
#                                                  Annotation  Distance to TSS  \
# PeakID
# Merged-chr4-148675243-4                          Intergenic          31905.0
# Merged-chr1-21036046-4   intron (NM_177409, intron 2 of 10)          43176.0
# Merged-chr5-150176797-3                          Intergenic         -83134.0
# Merged-chr4-149706201-4                          Intergenic          -4623.0
# Merged-chr4-141478572-1     exon (NM_019763, exon 12 of 16)          33899.0
#
#                         Gene Name                  location  \
# PeakID
# Merged-chr4-148675243-4     Gm572  chr4:148674722-148675722
# Merged-chr1-21036046-4      Tram2    chr1:21035549-21036549
# Merged-chr5-150176797-3       Fry  chr5:150176296-150177296
# Merged-chr4-149706201-4    Pik3cd  chr4:149705752-149706752
# Merged-chr4-141478572-1    Zbtb17  chr4:141478072-141479072
#
#                                                  Annotation  \
# PeakID
# Merged-chr4-148675243-4                          Intergenic
# Merged-chr1-21036046-4   intron (NM_177409, intron 2 of 10)
# Merged-chr5-150176797-3                          Intergenic
# Merged-chr4-149706201-4                          Intergenic
# Merged-chr4-141478572-1     exon (NM_019763, exon 12 of 16)
#
#                          00_cb6f1_c57 vs. 01_cb6f1_balb Log2 Fold Change  \
# PeakID
# Merged-chr4-148675243-4                                        -1.910547
# Merged-chr1-21036046-4                                          1.569088
# Merged-chr5-150176797-3                                        -4.411167
# Merged-chr4-149706201-4                                        -1.213511
# Merged-chr4-141478572-1                                        -1.300233
#
#                          00_cb6f1_c57 vs. 01_cb6f1_balb adj. p-value
# PeakID
# Merged-chr4-148675243-4                                     0.049799
# Merged-chr1-21036046-4                                      0.049758
# Merged-chr5-150176797-3                                     0.049739
# Merged-chr4-149706201-4                                     0.049739
# Merged-chr4-141478572-1                                     0.049596
